# %%
# !pip install transformers datasets
# !pip install rouge-score nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 47.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 34.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 16.6 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 90.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.9 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 10.9 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 17.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 17.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 10.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, charset-normalizer, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 charset-normalizer-3.1.0 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.2 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.26.1 xxhash-3.2.0 yarl-1.8.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rouge-score) (1.22.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from rouge-score) (1.15.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=ed2b3efe7e0c8edabaef1ef5efd2195c791048aa6f88e982a6fed90d649a5132
#   Stored in directory: /root/.cache/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM

model_name = 'Cpod/bart-base-finetuned-xsum'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/558M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBartForConditionalGeneration.
#
# All the layers of TFBartForConditionalGeneration were initialized from the model checkpoint at Cpod/bart-base-finetuned-xsum.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# Downloading (…)neration_config.json:   0%|          | 0.00/292 [00:00<?, ?B/s]

# %%
from datasets import load_dataset

raw_datasets = load_dataset("xsum")
# Out:
# Downloading builder script:   0%|          | 0.00/5.76k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.24k [00:00<?, ?B/s]
# Downloading and preparing dataset xsum/default to /root/.cache/huggingface/datasets/xsum/default/1.2.0/082863bf4754ee058a5b6f6525d0cb2b18eadb62c7b370b095d1364050a52b71...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/204045 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11332 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11334 [00:00<?, ? examples/s]
# Dataset xsum downloaded and prepared to /root/.cache/huggingface/datasets/xsum/default/1.2.0/082863bf4754ee058a5b6f6525d0cb2b18eadb62c7b370b095d1364050a52b71. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
max_input_length = 1024
max_target_length = 128


def preprocess_function(examples):
    inputs = [doc for doc in examples["document"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples["summary"], max_length=max_target_length, truncation=True
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/204045 [00:00<?, ? examples/s]
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/11332 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11334 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="np")

generation_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="np", pad_to_multiple_of=128)

# %%
test_dataset = model.prepare_tf_dataset(
    tokenized_datasets["test"],
    batch_size=8,
    shuffle=False,
    collate_fn=data_collator,
)

generation_dataset = model.prepare_tf_dataset(
    tokenized_datasets["test"],
    batch_size=8,
    shuffle=False,
    collate_fn=generation_data_collator
)
# Out:
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
from datasets import load_metric

rouge = load_metric("rouge")
# Out:
# <ipython-input-8-f0963467be44>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
# !git clone https://github.com/maszhongming/UniEval.git
# %cd UniEval
# !pip install -r requirements.txt
# Out:
# Cloning into 'UniEval'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 80 (delta 15), reused 73 (delta 13), pack-reused 0
# Unpacking objects: 100% (80/80), 1.97 MiB | 4.12 MiB/s, done.
# /content/UniEval
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers>=4.17.0.dev0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (4.26.1)
# Collecting accelerate
#   Downloading accelerate-0.17.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (2.10.1)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (3.19.6)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (3.7)
# Collecting py7zr
#   Downloading py7zr-0.20.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (1.13.1+cu116)
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: prettytable in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 2)) (5.4.8)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.8.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (0.70.14)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from rouge-score->-r requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from rouge-score->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 7)) (8.1.3)
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp39-cp39-manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 KB 38.7 MB/s eta 0:00:00
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.1 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64>=0.3.1
#   Downloading inflate64-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 KB 12.0 MB/s eta 0:00:00
# Collecting texttable
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 6.4 MB/s eta 0:00:00
# Collecting pyppmd<1.1.0,>=0.18.1
#   Downloading pyppmd-1.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 KB 17.5 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 KB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.3->-r requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prettytable->-r requirements.txt (line 11)) (0.2.6)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (1.26.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.17.0.dev0->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Installing collected packages: texttable, sentencepiece, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr, accelerate, evaluate
# Successfully installed accelerate-0.17.1 brotli-1.0.9 evaluate-0.4.0 inflate64-0.3.1 multivolumefile-0.2.3 py7zr-0.20.4 pybcj-1.0.1 pycryptodomex-3.17 pyppmd-1.0.0 pyzstd-0.15.4 sentencepiece-0.1.97 texttable-1.6.7

# %%
from metric.evaluator import get_evaluator

unieval = get_evaluator('summarization')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/3.13G [00:00<?, ?B/s]

# %%
import numpy as np
import nltk
from utils import convert_to_json


def metric_fn(eval_predictions):
    predictions, labels = eval_predictions
    decoded_predictions = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    for label in labels:
        label[label < 0] = tokenizer.pad_token_id  # Replace masked label tokens
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Rouge expects a newline after each sentence
    decoded_predictions_rouge = [
        "\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_predictions
    ]
    decoded_labels_rouge = [
        "\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels
    ]
    result = rouge.compute(
        predictions=decoded_predictions_rouge, references=decoded_labels_rouge, use_stemmer=True
    )
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    # Add mean generated length
    prediction_lens = [
        np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions
    ]
    result["gen_len"] = np.mean(prediction_lens)

    data = convert_to_json(output_list=decoded_predictions, 
                       src_list=raw_datasets["test"]["document"], ref_list=decoded_labels)
    
    unieval.evaluate(data, print_result=True)

    return result

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from transformers.keras_callbacks import KerasMetricCallback

# Workaround to allow callbacks to work during evaluation
KerasMetricCallback.on_test_begin = KerasMetricCallback.on_train_begin
KerasMetricCallback.on_test_batch_end = KerasMetricCallback.on_epoch_end
KerasMetricCallback.on_test_end = KerasMetricCallback.on_train_end

metric_callback = KerasMetricCallback(
    metric_fn, eval_dataset=generation_dataset, predict_with_generate=True, use_xla_generation=False
)

# %%
from transformers import AdamWeightDecay
import tensorflow as tf

learning_rate = 2e-5
weight_decay = 0.01

optimizer = AdamWeightDecay(learning_rate=learning_rate, weight_decay_rate=weight_decay)
model.compile(optimizer=optimizer)
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.

# %%
model.evaluate(test_dataset, callbacks=[metric_callback])
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/tf_utils.py:702: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Evaluating coherence of 11334 samples !!!
# 100%|██████████| 1417/1417 [14:05<00:00,  1.67it/s]
# Evaluating consistency of 11334 samples !!!
# 100%|██████████| 1417/1417 [14:04<00:00,  1.68it/s]
# Evaluating fluency of 11334 samples !!!
# 100%|██████████| 1417/1417 [01:54<00:00, 12.33it/s]
# Evaluating relevance of 11334 samples !!!
# 100%|██████████| 1417/1417 [01:54<00:00, 12.38it/s]
# Evaluation scores are shown below:
# +-------------+----------+
# |  Dimensions |  Score   |
# +-------------+----------+
# |  coherence  | 0.809327 |
# | consistency | 0.78722  |
# |   fluency   | 0.822813 |
# |  relevance  | 0.740254 |
# |   overall   | 0.789903 |
# +-------------+----------+
#    1/1417 [..............................] - ETA: 7784:11:14 - loss: 1.9232 - rouge1: 37.6046 - rouge2: 16.6458 - rougeL: 31.1819 - rougeLsum: 31.1814 - gen_len: 19.6421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ea9823e2c864> in <module>
# ----> 1 model.evaluate(test_dataset, callbacks=[metric_callback])
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2044                             logs = tmp_logs
#    2045                             end_step = step + data_handler.step_increment
# -> 2046                             callbacks.on_test_batch_end(end_step, logs)
#    2047
#    2048             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_test_batch_end(self, batch, logs)
#     496         """
#     497         if self._should_call_test_batch_hooks:
# --> 498             self._call_batch_hook(ModeKeys.TEST, "end", batch, logs=logs)
#     499
#     500     def on_predict_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     321             self._call_batch_begin_hook(mode, batch, logs)
#     322         elif hook == "end":
# --> 323             self._call_batch_end_hook(mode, batch, logs)
#     324         else:
#     325             raise ValueError(
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     344             self._batch_times.append(batch_time)
#     345
# --> 346         self._call_batch_hook_helper(hook_name, batch, logs)
#     347
#     348         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     392         for callback in self.callbacks:
#     393             hook = getattr(callback, hook_name)
# --> 394             hook(batch, logs)
#     395
#     396         if self._check_timing:
#
# /usr/local/lib/python3.9/dist-packages/transformers/keras_callbacks.py in on_epoch_end(self, epoch, logs)
#     226                     predictions = self.generation_function(generation_inputs, attention_mask=attention_mask)
#     227                 else:
# --> 228                     predictions = self.model.generate(generation_inputs, attention_mask=attention_mask)
#     229             else:
#     230                 predictions = self.model.predict_on_batch(batch)
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/tf_utils.py in generate(self, input_ids, generation_config, seed, **kwargs)
#     842
#     843             # 12. run beam search
# --> 844             return self.beam_search(
#     845                 input_ids,
#     846                 max_length=generation_config.max_length,
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/tf_utils.py in beam_search(self, input_ids, do_sample, max_length, pad_token_id, eos_token_id, length_penalty, early_stopping, logits_processor, logits_warper, num_return_sequences, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, **model_kwargs)
#    2226         ):
#    2227             maximum_iterations = max_length - cur_len
# -> 2228             cur_len, running_sequences, running_scores, sequences, scores, is_sent_finished, _ = tf.while_loop(
#    2229                 beam_search_cond_fn,
#    2230                 beam_search_body_fn,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     627                   func.__module__, arg_name, arg_value, 'in a future version'
#     628                   if date is None else ('after %s' % date), instructions)
# --> 629       return func(*args, **kwargs)
#     630
#     631     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2514
#    2515   """
# -> 2516   return while_loop(
#    2517       cond=cond,
#    2518       body=body,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2763                                               list(loop_vars))
#    2764       while cond(*loop_vars):
# -> 2765         loop_vars = body(*loop_vars)
#    2766         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2767           packed = True
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/control_flow_ops.py in <lambda>(i, lv)
#    2754         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    2755             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 2756         body = lambda i, lv: (i + 1, orig_body(*lv))
#    2757       try_to_pack = False
#    2758
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/tf_utils.py in beam_search_body_fn(cur_len, running_sequences, running_scores, sequences, scores, is_sent_finished, model_kwargs)
#    2042                 flatten_beam_dim(input_ids), use_cache=use_cache, **model_kwargs
#    2043             )
# -> 2044             model_outputs = self(
#    2045                 **model_inputs,
#    2046                 return_dict=True,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in __call__(self, *args, **kwargs)
#     559             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     560
# --> 561         return super().__call__(*args, **kwargs)
#     562
#     563     @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_tf_utils.py in run_call_with_unpacked_inputs(self, *args, **kwargs)
#     431
#     432         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 433         return func(self, **unpacked_inputs)
#     434
#     435     # Keras enforces the first layer argument to be passed, and checks it through `inspect.getfullargspec()`. This
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bart/modeling_tf_bart.py in call(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, labels, training)
#    1375                 )
#    1376
# -> 1377         outputs = self.model(
#    1378             input_ids,
#    1379             attention_mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_tf_utils.py in run_call_with_unpacked_inputs(self, *args, **kwargs)
#     431
#     432         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 433         return func(self, **unpacked_inputs)
#     434
#     435     # Keras enforces the first layer argument to be passed, and checks it through `inspect.getfullargspec()`. This
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bart/modeling_tf_bart.py in call(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, training, **kwargs)
#    1149             encoder_outputs = encoder_outputs.to_tuple()
#    1150
# -> 1151         decoder_outputs = self.decoder(
#    1152             decoder_input_ids,
#    1153             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_tf_utils.py in run_call_with_unpacked_inputs(self, *args, **kwargs)
#     431
#     432         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 433         return func(self, **unpacked_inputs)
#     434
#     435     # Keras enforces the first layer argument to be passed, and checks it through `inspect.getfullargspec()`. This
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bart/modeling_tf_bart.py in call(self, input_ids, inputs_embeds, attention_mask, position_ids, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     996             encoder_attention_mask = _expand_mask(encoder_attention_mask, tgt_len=input_shape[-1])
#     997
# --> 998         hidden_states = self.layernorm_embedding(hidden_states + positions)
#     999         hidden_states = self.dropout(hidden_states, training=training)
#    1000
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.9/dist-packages/keras/layers/normalization/layer_normalization.py in call(self, inputs)
#     288
#     289             # Calculate the moments on the last axis (layer activations).
# --> 290             mean, variance = tf.nn.moments(inputs, self.axis, keepdims=True)
#     291
#     292             scale, offset = _broadcast(self.gamma), _broadcast(self.beta)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/nn_impl.py in moments_v2(x, axes, shift, keepdims, name)
#    1417     Two `Tensor` objects: `mean` and `variance`.
#    1418   """
# -> 1419   return moments(x=x, axes=axes, shift=shift, name=name, keep_dims=keepdims)
#    1420
#    1421
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/nn_impl.py in moments(x, axes, shift, name, keep_dims, keepdims)
#    1363     y = math_ops.cast(x, dtypes.float32) if x.dtype == dtypes.float16 else x
#    1364     # Compute true mean while keeping the dims for proper broadcasting.
# -> 1365     mean = math_ops.reduce_mean(y, axes, keepdims=True, name="mean")
#    1366     # sample variance, not unbiased variance
#    1367     # Note: stop_gradient does not change the gradient that gets
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/math_ops.py in reduce_mean(input_tensor, axis, keepdims, name)
#    2638   return _may_reduce_to_scalar(
#    2639       keepdims, axis,
# -> 2640       gen_math_ops.mean(
#    2641           input_tensor, _ReductionDims(input_tensor, axis), keepdims,
#    2642           name=name))
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/gen_math_ops.py in mean(input, axis, keep_dims, name)
#    6277       pass
#    6278     try:
# -> 6279       return mean_eager_fallback(
#    6280           input, axis, keep_dims=keep_dims, name=name, ctx=_ctx)
#    6281     except _core._SymbolicException:
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/gen_math_ops.py in mean_eager_fallback(input, axis, keep_dims, name, ctx)
#    6306   keep_dims = _execute.make_bool(keep_dims, "keep_dims")
#    6307   _attr_T, (input,) = _execute.args_to_matching_eager([input], ctx, [_dtypes.float32, _dtypes.float64, _dtypes.int32, _dtypes.uint8, _dtypes.int16, _dtypes.int8, _dtypes.complex64, _dtypes.int64, _dtypes.qint8, _dtypes.quint8, _dtypes.qint32, _dtypes.bfloat16, _dtypes.uint16, _dtypes.complex128, _dtypes.half, _dtypes.uint32, _dtypes.uint64, ])
# -> 6308   _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    6309   _inputs_flat = [input, axis]
#    6310   _attrs = ("keep_dims", keep_dims, "T", _attr_T, "Tidx", _attr_Tidx)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#     252       # not list allowed dtypes, in which case we should skip this.
#     253       if dtype is None and allowed_dtypes:
# --> 254         tensor = ops.convert_to_tensor(t, ctx=ctx)
#     255         # If we did not match an allowed dtype, try again with the default
#     256         # dtype. This could be because we have an empty tensor and thus we
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1634
#    1635     if ret is None:
# -> 1636       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1637
#    1638     if ret is NotImplemented:
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#     344
#     345
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#     269
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# KeyboardInterrupt:
